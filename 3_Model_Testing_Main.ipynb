# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-preparation" data-toc-modified-id="Data-preparation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data preparation</a></span><ul class="toc-item"><li><span><a href="#Encoding-both-data-sources" data-toc-modified-id="Encoding-both-data-sources-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Encoding both data sources</a></span><ul class="toc-item"><li><span><a href="#One-Hot-Encoding" data-toc-modified-id="One-Hot-Encoding-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>One Hot Encoding</a></span></li><li><span><a href="#Target-Encoding" data-toc-modified-id="Target-Encoding-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Target Encoding</a></span></li><li><span><a href="#Target-Encoding-with-Cross-Validation" data-toc-modified-id="Target-Encoding-with-Cross-Validation-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Target Encoding with Cross Validation</a></span></li></ul></li><li><span><a href="#Define-evaluation-functions" data-toc-modified-id="Define-evaluation-functions-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Define evaluation functions</a></span></li></ul></li><li><span><a href="#Models-testing" data-toc-modified-id="Models-testing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Models testing</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Decision Tree Classifier</a></span><ul class="toc-item"><li><span><a href="#Base-models" data-toc-modified-id="Base-models-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Base models</a></span></li><li><span><a href="#Tuned-models" data-toc-modified-id="Tuned-models-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Tuned models</a></span></li></ul></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Random Forest Classifier</a></span><ul class="toc-item"><li><span><a href="#Base-models" data-toc-modified-id="Base-models-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Base models</a></span></li><li><span><a href="#Tuned-models" data-toc-modified-id="Tuned-models-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Tuned models</a></span></li></ul></li><li><span><a href="#KNeighbors-Classifier" data-toc-modified-id="KNeighbors-Classifier-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>KNeighbors Classifier</a></span><ul class="toc-item"><li><span><a href="#Baseline" data-toc-modified-id="Baseline-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Baseline</a></span></li><li><span><a href="#Tuned-models" data-toc-modified-id="Tuned-models-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Tuned models</a></span></li></ul></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>XGBoost</a></span><ul class="toc-item"><li><span><a href="#Base-models" data-toc-modified-id="Base-models-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Base models</a></span></li><li><span><a href="#Tuned-models" data-toc-modified-id="Tuned-models-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Tuned models</a></span></li></ul></li><li><span><a href="#Boosting-DTC" data-toc-modified-id="Boosting-DTC-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Boosting DTC</a></span><ul class="toc-item"><li><span><a href="#Base-models" data-toc-modified-id="Base-models-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Base models</a></span></li><li><span><a href="#Tuned-models" data-toc-modified-id="Tuned-models-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Tuned models</a></span></li></ul></li><li><span><a href="#Voting-Classifier-from-top-performers" data-toc-modified-id="Voting-Classifier-from-top-performers-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Voting Classifier from top performers</a></span></li><li><span><a href="#Neural-network" data-toc-modified-id="Neural-network-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Neural network</a></span><ul class="toc-item"><li><span><a href="#1st-iteration" data-toc-modified-id="1st-iteration-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>1st iteration</a></span></li><li><span><a href="#2nd-iteration" data-toc-modified-id="2nd-iteration-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>2nd iteration</a></span></li><li><span><a href="#3rd-iteration" data-toc-modified-id="3rd-iteration-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>3rd iteration</a></span></li></ul></li></ul></li><li><span><a href="#Plot-results-comparison" data-toc-modified-id="Plot-results-comparison-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Plot results comparison</a></span></li></ul></div>

# %%
from category_encoders import TargetEncoder
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import base
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier, VotingClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from tensorflow.keras import metrics
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras.utils import to_categorical
from xgboost import XGBClassifier
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data preparation

# %% [markdown]
# Let's prepare three datasets for further modelling:
# - One from with OHE.
# - A second one with Target Encoding.
# - A third one  with Target Encoding on Cross Validation.
#
# This will be later included in a complete pipeline.

# %% [markdown]
# ## Encoding both data sources

# %%
# open csv and create X and y
csv_clean = 'data_files/preproc_clean.csv'
df_clean = pd.read_csv(csv_clean)
X = df_clean.loc[:, df_clean.columns != 'is_booking']
y = df_clean['is_booking']

# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# columns by type
num_cols = X.select_dtypes(include=['int64', 'float64']).columns
cat_cols = X.select_dtypes(include=['object', 'bool']).columns

# %% [markdown]
# ### One Hot Encoding

# %%
# preproc pipeline with ohe
pipe_ohe = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='other')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))])

# fit on train, transform train and test
pipe_ohe.fit(X_train, y_train)
X_train_ohe = pipe_ohe.transform(X_train)
X_test_ohe = pipe_ohe.transform(X_test)

# %%
X_train_ohe
# Out:
# <58883x3375 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1413192 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Target Encoding

# %%
#find fair hyperparms for target ecoding on a dummy rfc
pipeline = Pipeline(steps= [('encoding', TargetEncoder()),
                            ('classifier', DecisionTreeClassifier())])
params = {
    'encoding__drop_invariant': [False, True],
    'encoding__min_samples_leaf': [1, 5, 10, 25, 50],
    'encoding__smoothing': [0., 0.01, 0.1]}

gs = GridSearchCV(estimator = pipeline,
                  param_grid = params,
                  cv=3,
                  n_jobs=-1)

gs.fit(X_train, y_train)

#unpack best params and print
te_bp = gs.best_params_
te_bp = {k[10:]: v for (k, v) in te_bp.items()}
print(te_bp)
# Out:
# /home/jupyter-igor.lopez/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py:925: UserWarning: One or more of the test scores are non-finite: [0.76368392 0.76344614 0.76210452        nan 0.76154406 0.76271587
#         nan 0.76190067 0.76111951        nan 0.76042318 0.76271583
#         nan 0.76444814 0.76193472 0.76652005 0.76592565 0.76548407
#         nan 0.76422733 0.76359898        nan 0.7659426  0.76373484
#         nan 0.76392161 0.76354797        nan 0.76438023 0.76376884]
#   category=UserWarning
# {'drop_invariant': True, 'min_samples_leaf': 1, 'smoothing': 0.0}

# %%
# add te hyperparams on preproc pipeline
pipe_te = Pipeline(steps=[
    ('encoder', TargetEncoder(**te_bp, handle_unknown='return_nan')),
    ('scaler', MinMaxScaler()),
    ('imputer', SimpleImputer(strategy='mean'))])

preproc = ColumnTransformer(
    [('cat_preproc', pipe_te, cat_cols),
     ('num_preproc', SimpleImputer(strategy='constant', fill_value=0), num_cols)],
    remainder='passthrough')


# fit on train, transform train and test
preproc.fit(X_train, y_train)
X_train_te = preproc.transform(X_train)
X_test_te = preproc.transform(X_test)


#convert to dfs
#X_train_te = pd.DataFrame(data=X_train_te, columns=X.columns)
#X_test_te = pd.DataFrame(data=X_test_te, columns=X.columns)

# %%
# sanity target rate check
print(y_train.sum()/X_train_te.shape[0],
      y_test.sum()/X_test_te.shape[0])
# Out:
# 0.13869877553793114 0.13873038516405137

# %% [markdown]
# ### Target Encoding with Cross Validation

# %%
# create encoder from https://brendanhasz.github.io/2019/03/04/target-encoding#cross-fold-target-encoding

class TargetEncoderCV(TargetEncoder):
    """Cross-fold target encoder.
    """
    
    def __init__(self, n_splits=3, shuffle=True, cols=None):
        """Cross-fold target encoding for categorical features.
        
        Parameters
        ----------
        n_splits : int
            Number of cross-fold splits. Default = 3.
        shuffle : bool
            Whether to shuffle the data when splitting into folds.
        cols : list of str
            Columns to target encode.
        """
        self.n_splits = n_splits
        self.shuffle = shuffle
        self.cols = cols
        

    def fit(self, X, y):
        """Fit cross-fold target encoder to X and y
        
        Parameters
        ----------
        X : pandas DataFrame, shape [n_samples, n_columns]
            DataFrame containing columns to encode
        y : pandas Series, shape = [n_samples]
            Target values.
            
        Returns
        -------
        self : encoder
            Returns self.
        """
        self._target_encoder = TargetEncoder(cols=self.cols)
        self._target_encoder.fit(X, y)
        return self

    
    def transform(self, X, y=None):
        """Perform the target encoding transformation.

        Uses cross-fold target encoding for the training fold,
        and uses normal target encoding for the test fold.

        Parameters
        ----------
        X : pandas DataFrame, shape [n_samples, n_columns]
            DataFrame containing columns to encode

        Returns
        -------
        pandas DataFrame
            Input DataFrame with transformed columns
        """

        # Use target encoding from fit() if this is test data
        if y is None:
            return self._target_encoder.transform(X)

        # Compute means for each fold
        self._train_ix = []
        self._test_ix = []
        self._fit_tes = []
        kf = KFold(n_splits=self.n_splits, shuffle=self.shuffle)
        for train_ix, test_ix in kf.split(X):
            self._train_ix.append(train_ix)
            self._test_ix.append(test_ix)
            te = TargetEncoder(cols=self.cols)
            if isinstance(X, pd.DataFrame):
                self._fit_tes.append(te.fit(X.iloc[train_ix,:],
                                            y.iloc[train_ix]))
            elif isinstance(X, np.ndarray):
                self._fit_tes.append(te.fit(X[train_ix,:],
                                            y[train_ix]))
            else:
                raise TypeError('X must be DataFrame or ndarray')

        # Apply means across folds
        Xo = X.copy()
        for ix in range(len(self._test_ix)):
            test_ix = self._test_ix[ix]
            if isinstance(X, pd.DataFrame):
                Xo.iloc[test_ix,:] = \
                    self._fit_tes[ix].transform(X.iloc[test_ix,:])
            elif isinstance(X, np.ndarray):
                Xo[test_ix,:] = \
                    self._fit_tes[ix].transform(X[test_ix,:])
            else:
                raise TypeError('X must be DataFrame or ndarray')
        return Xo

            
    def fit_transform(self, X, y=None):
        """Fit and transform the data via target encoding.
        
        Parameters
        ----------
        X : pandas DataFrame, shape [n_samples, n_columns]
            DataFrame containing columns to encode
        y : pandas Series, shape = [n_samples]
            Target values (required!).

        Returns
        -------
        pandas DataFrame
            Input DataFrame with transformed columns
        """
        return self.fit(X, y).transform(X, y)

# %%
# add tecv hyperparams on preproc pipeline
pipe_tecv = Pipeline(steps=[
    ('encoder', TargetEncoderCV()),
    ('scaler', MinMaxScaler()),
    ('imputer', SimpleImputer(strategy='mean'))])

preproc_tecv = ColumnTransformer(
    [('cat_preproc', pipe_tecv, cat_cols),
     ('num_preproc', SimpleImputer(strategy='constant', fill_value=0), num_cols)],
    remainder='passthrough')


# fit on train, transform train and test
preproc_tecv.fit(X_train, y_train)
X_train_tecv = preproc_tecv.transform(X_train)
X_test_tecv = preproc_tecv.transform(X_test)


#convert to dfs
X_train_tecv = pd.DataFrame(data=X_train_tecv, columns=X.columns)
X_test_tecv = pd.DataFrame(data=X_test_tecv, columns=X.columns)

# %%
# sanity target rate check
print(y_train.sum()/X_train_tecv.shape[0],
      y_test.sum()/X_test_tecv.shape[0])
# Out:
# 0.13869877553793114 0.13873038516405137

# %% [markdown]
# ## Define evaluation functions

# %% [markdown]
# Evaluate also twice:
# - each model with each preproc, classification report
# - each model with each preproc, main metrics and Confusion Matrix over test set

# %%
def eval_report(models):

    for (n, model) in models:

        if 'ohe' in n.lower():
            model.fit(X_train_ohe, y_train)
            ytrain = y_train
            ytest = y_test
            ypred_train = model.predict(X_train_ohe)
            ypred_test = model.predict(X_test_ohe)

            
        if ' te ' in n.lower():
            model.fit(X_train_te, y_train)
            ytrain = y_train
            ytest = y_test
            ypred_train = model.predict(X_train_te)
            ypred_test = model.predict(X_test_te)
        
        
        if ' tecv' in n.lower():
            model.fit(X_train_tecv, y_train)
            ytrain = y_train
            ytest = y_test
            ypred_train = model.predict(X_train_tecv)
            ypred_test = model.predict(X_test_tecv)   
        
        print(n)
        print(f'Train Accuracy: {round(accuracy_score(ytrain, ypred_train)*100,3)} %')
        print((f'Test Accuracy: {round(accuracy_score(ytest, ypred_test)*100,3)} %'))
        print(f'Train F1: {round(f1_score(ytrain, ypred_train)*100,3)} %')
        print((f'Test F1: {round(f1_score(ytest, ypred_test)*100,3)} % \n'))
        print(n, 'classification report on test')
        print(classification_report(ytest, ypred_test), '\n\n')

# %%
def eval_multi(models):

    seed = 42
    results = []
    names = []
    ypred_ohe=[]
    ypred_te=[]   
    
    scoring = {'accuracy' : make_scorer(accuracy_score),
               'f1_score' : make_scorer(f1_score),
               'roc_auc': make_scorer(roc_auc_score),
               'log_loss': make_scorer(log_loss)}

    for n, model in models:

        if 'ohe' in n.lower():      
            kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=seed)
            cv_r = cross_validate(model, X_train_ohe, y_train, cv=kfold, scoring=scoring)
            results.append(cv_r)
            names.append(n)
            ypred = model.fit(X_train_ohe, y_train).predict(X_test_ohe)
            ypred_ohe = ypred.copy()
            
        if ' te ' in n.lower():
            kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=seed)
            cv_r = cross_validate(model, X_train_te, y_train, cv=kfold, scoring=scoring)
            results.append(cv_r)
            names.append(n)
            ypred = model.fit(X_train_te, y_train).predict(X_test_te)
            ypred_te = ypred.copy()
            
        if ' tecv' in n.lower():
            kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=seed)
            cv_r = cross_validate(model, X_train_tecv, y_train, cv=kfold, scoring=scoring)
            results.append(cv_r)
            names.append(n)
            ypred = model.fit(X_train_tecv, y_train).predict(X_test_tecv)
            ypred_tecv = ypred.copy() 
            
    fig, ax = plt.subplots(4, 2, figsize=(12,13))
    fig.tight_layout(pad=4, rect=[0, 0.03, 1, 0.95])
    fig.suptitle('Models Comparison on cross validation', size=18)

    # build scores by metric
    acc = [results[i]['test_accuracy'] for i, r in enumerate(results)]
    f1 = [results[i]['test_f1_score'] for i, r in enumerate(results)]
    roc_auc = [results[i]['test_roc_auc'] for i, r in enumerate(results)]
    logloss = [results[i]['test_log_loss'] for i, r in enumerate(results)]
    
    # build cms
    cf_matrix_ohe = confusion_matrix(y_test, ypred_ohe)
    cf_matrix_te = confusion_matrix(y_test, ypred_te)
    cf_matrix_tecv = confusion_matrix(y_test, ypred_tecv)
    
    # plot
    sns.boxplot(data=acc, color='cornflowerblue', ax=ax[0,0]).set(xticklabels=names, title='accuracy on test')
    sns.boxplot(data=f1, color='cornflowerblue', ax=ax[0,1]).set(xticklabels=names, title='f1 on test')
    sns.boxplot(data=roc_auc, color='cornflowerblue', ax=ax[1,0]).set(xticklabels=names, title='roc_auc on test')
    sns.boxplot(data=logloss, color='cornflowerblue', ax=ax[1,1]).set(xticklabels=names, title='logloss on test')
    
    sns.heatmap(cf_matrix_ohe/np.sum(cf_matrix_ohe), annot=True, fmt='.2%', cmap='Blues', ax=ax[2,0]).\
    set_title('OHE CM on test')
    sns.heatmap(cf_matrix_te/np.sum(cf_matrix_te), annot=True, fmt='.2%', cmap='Blues', ax=ax[2,1]).\
    set_title('TE CM on test')
    sns.heatmap(cf_matrix_tecv/np.sum(cf_matrix_tecv), annot=True, fmt='.2%', cmap='Blues', ax=ax[3,0]).\
    set_title('TECV CM on test')
    ax[3,1].axis('off')
    
    return pd.DataFrame(results, names).apply(pd.Series.explode).reset_index().rename(columns={'index': 'model'})

# %% [markdown]
# # Models testing

# %% [markdown]
# When creating models, store name and model on a tuple, where the first item is the model name containing a reference to the data encoding that will be used for fit and predict.
#
# **('DTC ohe base', DecisionTreeClassifier())** --> will use a 'naked' random forest classifier on the **ohe dataset**

# %% [markdown]
# ## Decision Tree Classifier

# %% [markdown]
# ### Base models

# %%
models_dtc_base = [
    ('DTC ohe base', DecisionTreeClassifier()),
    ('DTC te base', DecisionTreeClassifier()),
    ('DTC tecv base', DecisionTreeClassifier())]

# %%
# %%time

eval_report(models_dtc_base)
# Out:
# DTC ohe base
# Train Accuracy: 99.613 %
# Test Accuracy: 79.611 %
# Train F1: 98.585 %
# Test F1: 19.864 %
#
# DTC ohe base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88     16905
#            1       0.22      0.18      0.20      2723
#
#     accuracy                           0.80     19628
#    macro avg       0.55      0.54      0.54     19628
# weighted avg       0.78      0.80      0.79     19628
#
#
#
# DTC te base
# Train Accuracy: 99.097 %
# Test Accuracy: 76.753 %
# Train F1: 96.642 %
# Test F1: 22.067 %
#
# DTC te base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86     16905
#            1       0.21      0.24      0.22      2723
#
#     accuracy                           0.77     19628
#    macro avg       0.54      0.55      0.54     19628
# weighted avg       0.78      0.77      0.77     19628
#
#
#
# DTC tecv base
# Train Accuracy: 99.613 %
# Test Accuracy: 76.691 %
# Train F1: 98.585 %
# Test F1: 22.602 %
#
# DTC tecv base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86     16905
#            1       0.21      0.25      0.23      2723
#
#     accuracy                           0.77     19628
#    macro avg       0.54      0.55      0.54     19628
# weighted avg       0.78      0.77      0.77     19628
#
#
#
# CPU times: user 20.4 s, sys: 0 ns, total: 20.4 s
# Wall time: 1min 3s

# %%
# %%time

dtc_base = eval_multi(models_dtc_base)
results = dtc_base.copy()
dtc_base
# Out:
# CPU times: user 55.6 s, sys: 103 ms, total: 55.7 s
# Wall time: 3min 5s
#            model  fit_time score_time test_accuracy test_f1_score  \
# 0   DTC ohe base   34.9023  0.0947609       0.79514      0.194995
# 1   DTC ohe base   43.2993   0.166467      0.792541      0.182658
# 2   DTC ohe base   32.9114   0.101605      0.791359       0.18475
# 3    DTC te base   0.62035  0.0745378      0.770939      0.215632
# 4    DTC te base  0.611183  0.0669165      0.773945      0.231954
# 5    DTC te base  0.612273  0.0225692      0.773883       0.22195
# 6  DTC tecv base    1.3896   0.109591      0.766609      0.222637
# 7  DTC tecv base   1.38918   0.100555      0.770634       0.22646
# 8  DTC tecv base   1.77716   0.144652      0.766495       0.21725
#
#   test_roc_auc test_log_loss
# 0     0.536635        7.0757
# 1     0.530191       7.16544
# 2     0.530898       7.20629
# 3     0.542775       7.91157
# 4     0.552514       7.80775
# 5     0.546798        7.8099
# 6     0.546118       8.06114
# 7     0.548897       7.92213
# 8     0.542972       8.06507

# %% [markdown]
# ### Tuned models

# %%
estimator = DecisionTreeClassifier()

gs = GridSearchCV(estimator,
                  {'criterion': ['gini', 'entropy'],
                   'min_samples_split': [2, 5, 10],
                   'min_samples_leaf': [1, 5, 10],
                   'max_depth': [100, 250, 500]},
                  scoring='accuracy',
                  cv=3,
                  n_jobs=-1,
                  verbose=10)

# %%
# %%time

gs.fit(X_train_ohe, y_train)
dtc_ohe = pd.DataFrame(gs.cv_results_)
dtc_ohe_bp = gs.best_params_
dtc_ohe_bp
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# CPU times: user 8.09 s, sys: 66.1 ms, total: 8.16 s
# Wall time: 14min 10s
# {'criterion': 'gini',
#  'max_depth': 100,
#  'min_samples_leaf': 10,
#  'min_samples_split': 10}

# %%
# %%time

gs.fit(X_train_te, y_train)
dtc_te = pd.DataFrame(gs.cv_results_)
dtc_te_bp = gs.best_params_
dtc_te_bp
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# CPU times: user 1.14 s, sys: 42.7 ms, total: 1.18 s
# Wall time: 39.4 s
# {'criterion': 'entropy',
#  'max_depth': 100,
#  'min_samples_leaf': 10,
#  'min_samples_split': 5}

# %%
models_dtc_tuned = [
    ('DTC ohe tuned', DecisionTreeClassifier(**dtc_ohe_bp)),
    ('DTC te tuned', DecisionTreeClassifier(**dtc_te_bp)),
    ('DTC tecv tuned', DecisionTreeClassifier(**dtc_te_bp))]

# %%
# %%time

eval_report(models_dtc_tuned)
# Out:
# DTC ohe tuned
# Train Accuracy: 86.708 %
# Test Accuracy: 84.904 %
# Train F1: 20.092 %
# Test F1: 8.465 %
#
# DTC ohe tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92     16905
#            1       0.27      0.05      0.08      2723
#
#     accuracy                           0.85     19628
#    macro avg       0.57      0.51      0.50     19628
# weighted avg       0.78      0.85      0.80     19628
#
#
#
# DTC te tuned
# Train Accuracy: 87.665 %
# Test Accuracy: 83.223 %
# Train F1: 36.507 %
# Test F1: 14.222 %
#
# DTC te tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91     16905
#            1       0.24      0.10      0.14      2723
#
#     accuracy                           0.83     19628
#    macro avg       0.56      0.53      0.52     19628
# weighted avg       0.78      0.83      0.80     19628
#
#
#
# DTC tecv tuned
# Train Accuracy: 87.811 %
# Test Accuracy: 82.836 %
# Train F1: 38.017 %
# Test F1: 13.282 %
#
# DTC tecv tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.90     16905
#            1       0.22      0.09      0.13      2723
#
#     accuracy                           0.83     19628
#    macro avg       0.54      0.52      0.52     19628
# weighted avg       0.78      0.83      0.80     19628
#
#
#
# CPU times: user 8.53 s, sys: 523 µs, total: 8.53 s
# Wall time: 13 s

# %%
# %%time

dtc_tuned = eval_multi(models_dtc_tuned)
results = pd.concat([results, dtc_tuned], ignore_index=True)
dtc_tuned
# Out:
# CPU times: user 22.7 s, sys: 131 ms, total: 22.8 s
# Wall time: 34.5 s
#             model  fit_time score_time test_accuracy test_f1_score  \
# 0   DTC ohe tuned   5.67888  0.0238137      0.851691     0.0825717
# 1   DTC ohe tuned   5.81219  0.0585294      0.848838     0.0873577
# 2   DTC ohe tuned   5.89715  0.0226803      0.850818     0.0867124
# 3    DTC te tuned  0.411343  0.0565221      0.834726      0.163055
# 4    DTC te tuned  0.423725   0.021836      0.831771       0.15593
# 5    DTC te tuned  0.397554  0.0566456      0.833342      0.153687
# 6  DTC tecv tuned  0.553188  0.0239153      0.835694      0.170738
# 7  DTC tecv tuned  0.513584  0.0591338      0.828256      0.161234
# 8  DTC tecv tuned  0.489532  0.0246446      0.833902      0.174265
#
#   test_roc_auc test_log_loss
# 0     0.514599       5.12241
# 1     0.514657       5.22095
# 2     0.515329       5.15259
# 3     0.533261        5.7084
# 4     0.529858       5.81046
# 5     0.529533        5.7562
# 6     0.536289       5.67497
# 7     0.530744       5.93188
# 8     0.537102       5.73685

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# ### Base models

# %%
models_rfc_base = [
    ('RFC ohe base', RandomForestClassifier()),
    ('RFC te base', RandomForestClassifier()),
    ('RFC tecv base', RandomForestClassifier())]

# %%
# %%time

eval_report(models_rfc_base)
# Out:
# RFC ohe base
# Train Accuracy: 99.611 %
# Test Accuracy: 86.428 %
# Train F1: 98.582 %
# Test F1: 10.604 %
#
# RFC ohe base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93     16905
#            1       0.61      0.06      0.11      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.74      0.53      0.52     19628
# weighted avg       0.83      0.86      0.81     19628
#
#
#
# RFC te base
# Train Accuracy: 99.095 %
# Test Accuracy: 85.485 %
# Train F1: 96.659 %
# Test F1: 14.316 %
#
# RFC te base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92     16905
#            1       0.40      0.09      0.14      2723
#
#     accuracy                           0.85     19628
#    macro avg       0.63      0.53      0.53     19628
# weighted avg       0.80      0.85      0.81     19628
#
#
#
# RFC tecv base
# Train Accuracy: 99.606 %
# Test Accuracy: 85.867 %
# Train F1: 98.562 %
# Test F1: 12.602 %
#
# RFC tecv base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92     16905
#            1       0.44      0.07      0.13      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.66      0.53      0.52     19628
# weighted avg       0.81      0.86      0.81     19628
#
#
#
# CPU times: user 2min 23s, sys: 289 ms, total: 2min 24s
# Wall time: 5min 42s

# %%
# %%time

rfc_base = eval_multi(models_rfc_base)
results = pd.concat([results, rfc_base], ignore_index=True)
rfc_base
# Out:
# CPU times: user 6min 21s, sys: 285 ms, total: 6min 22s
# Wall time: 15min 45s
#            model fit_time score_time test_accuracy test_f1_score test_roc_auc  \
# 0   RFC ohe base  108.671    1.10689      0.863155     0.0731539     0.517401
# 1   RFC ohe base  116.197    2.91338      0.861575     0.0698391      0.51589
# 2   RFC ohe base  211.672    1.40006      0.862231     0.0714286      0.51656
# 3    RFC te base  12.2852      1.601      0.854748      0.114871     0.524696
# 4    RFC te base  15.6981   0.997648      0.854748      0.123578     0.527177
# 5    RFC te base  19.1966     1.9051      0.853671      0.120637     0.525923
# 6  RFC tecv base  12.6226    1.28852      0.860149      0.100295     0.522899
# 7  RFC tecv base  14.4824    1.90201      0.858366      0.103804     0.523115
# 8  RFC tecv base  14.1093    1.20825      0.858155      0.112811     0.525444
#
#   test_log_loss
# 0       4.72647
# 1       4.78102
# 2       4.75839
# 3       5.01683
# 4       5.01683
# 5       5.05404
# 6        4.8303
# 7       4.89189
# 8       4.89918

# %% [markdown]
# ### Tuned models

# %%
estimator = RandomForestClassifier()

gs = GridSearchCV(estimator,
                  {'n_estimators': [5, 10, 50],
                   'min_samples_split': [1, 2, 5],
                   'min_samples_leaf': [1, 2, 10]},
                  scoring='accuracy',
                  cv=3,
                  n_jobs=-1,
                  verbose=10)

# %%
# %%time

gs.fit(X_train_ohe, y_train)
rfc_ohe = pd.DataFrame(gs.cv_results_)
rfc_ohe_bp = gs.best_params_
rfc_ohe_bp
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# /home/jupyter-igor.lopez/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py:925: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.84071806 0.85754801 0.86260889
#  0.85440618 0.85953499 0.86296554        nan        nan        nan
#  0.86099554 0.86155597 0.86143709 0.86092761 0.86143709 0.86148803
#         nan        nan        nan 0.86130122 0.86130122 0.86130122
#  0.86130122 0.86130122 0.86130122]
#   category=UserWarning
# CPU times: user 40.5 s, sys: 141 ms, total: 40.7 s
# Wall time: 9min 15s
# {'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}

# %%
# %%time

gs.fit(X_train_te, y_train)
rfc_te = pd.DataFrame(gs.cv_results_)
rfc_te_bp = gs.best_params_
rfc_te_bp
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# /home/jupyter-igor.lopez/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py:925: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.82996788 0.8501775  0.85421938
#  0.8421276  0.85265696 0.85978976        nan        nan        nan
#  0.85007558 0.85615543 0.86023129 0.84886979 0.85676678 0.8601294
#         nan        nan        nan 0.86018038 0.86111442 0.86153899
#  0.86067286 0.86046907 0.861522  ]
#   category=UserWarning
# CPU times: user 4.01 s, sys: 26.7 ms, total: 4.03 s
# Wall time: 1min 28s
# {'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 50}

# %%
models_rfc_tuned = [
    ('RFC ohe tuned', RandomForestClassifier(**rfc_ohe_bp)),
    ('RFC te tuned', RandomForestClassifier(**rfc_te_bp)),
    ('RFC tecv tuned', RandomForestClassifier(**rfc_te_bp))]

# %%
# %%time

eval_report(models_rfc_tuned)
# Out:
# RFC ohe tuned
# Train Accuracy: 91.087 %
# Test Accuracy: 86.448 %
# Train F1: 52.695 %
# Test F1: 6.007 %
#
# RFC ohe tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     16905
#            1       0.79      0.03      0.06      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.83      0.51      0.49     19628
# weighted avg       0.86      0.86      0.81     19628
#
#
#
# RFC te tuned
# Train Accuracy: 86.516 %
# Test Accuracy: 86.04 %
# Train F1: 5.902 %
# Test F1: 1.083 %
#
# RFC te tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     16905
#            1       0.32      0.01      0.01      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.59      0.50      0.47     19628
# weighted avg       0.79      0.86      0.80     19628
#
#
#
# RFC tecv tuned
# Train Accuracy: 86.414 %
# Test Accuracy: 86.071 %
# Train F1: 4.123 %
# Test F1: 0.509 %
#
# RFC tecv tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     16905
#            1       0.28      0.00      0.01      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.57      0.50      0.47     19628
# weighted avg       0.78      0.86      0.80     19628
#
#
#
# CPU times: user 50.4 s, sys: 11 ms, total: 50.4 s
# Wall time: 2min 28s

# %%
# %%time

rfc_tuned = eval_multi(models_rfc_tuned)
results = pd.concat([results, rfc_tuned], ignore_index=True)
rfc_tuned
# Out:
# CPU times: user 2min 8s, sys: 145 ms, total: 2min 8s
# Wall time: 5min 38s
#             model fit_time score_time test_accuracy test_f1_score  \
# 0   RFC ohe tuned  63.4194   0.412881       0.86346     0.0462633
# 1   RFC ohe tuned  26.0538   0.404981      0.862798     0.0399287
# 2   RFC ohe tuned  45.5134   0.712321      0.862536     0.0371163
# 3    RFC te tuned  8.87534   0.822715       0.86183     0.0109409
# 4    RFC te tuned  8.70068   0.763907      0.861779     0.0180963
# 5    RFC te tuned  8.41138   0.324934      0.861568     0.0244165
# 6  RFC tecv tuned  8.01285   0.800698      0.861677      0.008038
# 7  RFC tecv tuned  8.10822   0.384661      0.861728    0.00948905
# 8  RFC tecv tuned  6.71337    0.40709      0.861619     0.0180766
#
#   test_roc_auc test_log_loss
# 0      0.51126       4.71591
# 1     0.509514       4.73879
# 2     0.508724       4.74783
# 3     0.502607       4.77222
# 4     0.504147       4.77398
# 5     0.505388       4.78126
# 6     0.501902        4.7775
# 7     0.502269       4.77574
# 8      0.50403        4.7795

# %% [markdown]
# ## KNeighbors Classifier

# %% [markdown]
# ### Baseline

# %%
models_knc_base = [
    ('KNC ohe base', KNeighborsClassifier()),
    ('KNC te base', KNeighborsClassifier()),
    ('KNC tecv base', KNeighborsClassifier())]

# %%
# %%time

eval_report(models_knc_base)
# Out:
# KNC ohe base
# Train Accuracy: 87.125 %
# Test Accuracy: 84.476 %
# Train F1: 26.161 %
# Test F1: 10.671 %
#
# KNC ohe base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91     16905
#            1       0.26      0.07      0.11      2723
#
#     accuracy                           0.84     19628
#    macro avg       0.57      0.52      0.51     19628
# weighted avg       0.78      0.84      0.80     19628
#
#
#
# KNC te base
# Train Accuracy: 87.433 %
# Test Accuracy: 84.008 %
# Train F1: 30.712 %
# Test F1: 12.733 %
#
# KNC te base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91     16905
#            1       0.26      0.08      0.13      2723
#
#     accuracy                           0.84     19628
#    macro avg       0.56      0.52      0.52     19628
# weighted avg       0.78      0.84      0.80     19628
#
#
#
# KNC tecv base
# Train Accuracy: 87.312 %
# Test Accuracy: 84.104 %
# Train F1: 29.366 %
# Test F1: 11.111 %
#
# KNC tecv base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91     16905
#            1       0.25      0.07      0.11      2723
#
#     accuracy                           0.84     19628
#    macro avg       0.56      0.52      0.51     19628
# weighted avg       0.78      0.84      0.80     19628
#
#
#
# CPU times: user 7min 7s, sys: 1min 11s, total: 8min 19s
# Wall time: 31min 6s

# %%
# %%time

knc_base = eval_multi(models_knc_base)
results = pd.concat([results, knc_base], ignore_index=True)
knc_base
# Out:
# CPU times: user 4min 55s, sys: 49.7 s, total: 5min 45s
# Wall time: 30min 7s
#            model    fit_time score_time test_accuracy test_f1_score  \
# 0   KNC ohe base     0.10608    272.803      0.843489     0.0857143
# 1   KNC ohe base   0.0812504    223.111      0.841349     0.0873388
# 2   KNC ohe base   0.0618112     200.53      0.843634     0.0890472
# 3    KNC te base  0.00567102    91.0008      0.842521      0.129541
# 4    KNC te base   0.0562847    83.1114       0.84354       0.13566
# 5    KNC te base  0.00642657    87.8207      0.843838      0.128023
# 6  KNC tecv base  0.00944614    79.5223      0.846291       0.12271
# 7  KNC tecv base   0.0782862    96.8973      0.844304      0.132804
# 8  KNC tecv base   0.0138955     95.086       0.84287      0.115318
#
#   test_roc_auc test_log_loss
# 0     0.511841       5.40572
# 1     0.511388       5.47963
# 2     0.512853       5.40072
# 3     0.524533       5.43916
# 4     0.526832       5.40397
# 5      0.52453       5.39368
# 6     0.523793       5.30894
# 7     0.526197       5.37757
# 8      0.52027       5.42712

# %% [markdown]
# ### Tuned models

# %%
estimator = KNeighborsClassifier()

gs = GridSearchCV(estimator,
                  {'n_neighbors': [3, 5, 10],
                   'algorithm': ['auto', 'brute'], #<------ provoking 'cannot use tree with sparse input' (OHE)
                   'leaf_size': [10, 30, 50]},
                  scoring='accuracy',
                  cv=3,
                  n_jobs=-1, #<------ provoking 'The exit codes of the workers are {SIGKILL(-9)}'
                  verbose=10)

# %%
# %%time

gs.fit(X_train_ohe, y_train)
knc_ohe = pd.DataFrame(gs.cv_results_)
knc_ohe_bp = gs.best_params_
knc_ohe_bp
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# CPU times: user 385 ms, sys: 158 ms, total: 543 ms
# Wall time: 1h 15min 27s
# {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 10}

# %%
# %%time

gs.fit(X_train_te, y_train)
knc_te = pd.DataFrame(gs.cv_results_)
knc_te_bp = gs.best_params_
knc_te_bp
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# CPU times: user 306 ms, sys: 24.3 ms, total: 330 ms
# Wall time: 39min 31s
# {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 10}

# %%
models_knc_tuned = [
    ('KNC ohe tuned', KNeighborsClassifier(**knc_ohe_bp)),
    ('KNC te tuned', KNeighborsClassifier(**knc_te_bp)),
    ('KNC tecv tuned', KNeighborsClassifier(**knc_te_bp))]

# %%
# %%time

eval_report(models_knc_tuned)
# Out:
# KNC ohe tuned
# Train Accuracy: 86.286 %
# Test Accuracy: 85.918 %
# Train F1: 4.607 %
# Test F1: 2.125 %
#
# KNC ohe tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     16905
#            1       0.30      0.01      0.02      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.58      0.50      0.47     19628
# weighted avg       0.78      0.86      0.80     19628
#
#
#
# KNC te tuned
# Train Accuracy: 86.541 %
# Test Accuracy: 85.668 %
# Train F1: 10.503 %
# Test F1: 5.254 %
#
# KNC te tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92     16905
#            1       0.32      0.03      0.05      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.59      0.51      0.49     19628
# weighted avg       0.79      0.86      0.80     19628
#
#
#
# KNC tecv tuned
# Train Accuracy: 86.417 %
# Test Accuracy: 85.898 %
# Train F1: 8.217 %
# Test F1: 4.683 %
#
# KNC tecv tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92     16905
#            1       0.38      0.02      0.05      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.62      0.51      0.49     19628
# weighted avg       0.80      0.86      0.80     19628
#
#
#
# CPU times: user 6min 16s, sys: 1min 2s, total: 7min 19s
# Wall time: 1h 3min 14s

# %%
# %%time

knc_tuned = eval_multi(models_knc_tuned)
results = pd.concat([results, knc_tuned], ignore_index=True)
knc_tuned
# Out:
# CPU times: user 4min 49s, sys: 46.3 s, total: 5min 35s
# Wall time: 39min 43s
#             model    fit_time score_time test_accuracy test_f1_score  \
# 0   KNC ohe tuned   0.0957427    252.067      0.858977     0.0184397
# 1   KNC ohe tuned   0.0196865    242.516      0.858722      0.021179
# 2   KNC ohe tuned    0.079457    270.424      0.859581     0.0254597
# 3    KNC te tuned  0.00534868    114.388      0.859385     0.0502409
# 4    KNC te tuned  0.00538707    111.494      0.858417     0.0544403
# 5    KNC te tuned  0.00537205    119.498      0.859072     0.0566166
# 6  KNC tecv tuned   0.0934098     132.48      0.860251      0.039902
# 7  KNC tecv tuned    0.201379    179.108      0.858722     0.0394874
# 8  KNC tecv tuned  0.00971198    191.687      0.858919     0.0415369
#
#   test_roc_auc test_log_loss
# 0     0.502646       4.87077
# 1     0.503142       4.87956
# 2     0.504542        4.8499
# 3     0.510126       4.85669
# 4     0.510667       4.89012
# 5      0.51149        4.8675
# 6     0.508163       4.82677
# 7     0.507302       4.87957
# 8     0.507857       4.87278

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ### Base models

# %%
models_xgb_base = [
    ('XGB ohe base', XGBClassifier(use_label_encoder=False)),
    ('XGB te base', XGBClassifier(use_label_encoder=False)),
    ('XGB tecv base', XGBClassifier(use_label_encoder=False))]

# %%
# %%time

eval_report(models_xgb_base)
# Out:
# [13:47:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB ohe base
# Train Accuracy: 86.404 %
# Test Accuracy: 86.132 %
# Train F1: 4.326 %
# Test F1: 1.875 %
#
# XGB ohe base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     16905
#            1       0.51      0.01      0.02      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.69      0.50      0.47     19628
# weighted avg       0.81      0.86      0.80     19628
#
#
#
# [13:55:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB te base
# Train Accuracy: 87.231 %
# Test Accuracy: 85.75 %
# Train F1: 16.558 %
# Test F1: 5.539 %
#
# XGB te base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92     16905
#            1       0.34      0.03      0.06      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.60      0.51      0.49     19628
# weighted avg       0.79      0.86      0.80     19628
#
#
#
# [14:04:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB tecv base
# Train Accuracy: 87.343 %
# Test Accuracy: 85.719 %
# Train F1: 17.637 %
# Test F1: 6.16 %
#
# XGB tecv base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92     16905
#            1       0.35      0.03      0.06      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.61      0.51      0.49     19628
# weighted avg       0.79      0.86      0.80     19628
#
#
#
# CPU times: user 5min 35s, sys: 1.35 s, total: 5min 37s
# Wall time: 25min 19s

# %%
# %%time

xgb_base = eval_multi(models_xgb_base)
results = pd.concat([results, xgb_base], ignore_index=True)
xgb_base
# Out:
# [14:12:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:20:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:28:09] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:36:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:44:40] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:52:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:00:36] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:08:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:17:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:25:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:33:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:42:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CPU times: user 21min 51s, sys: 3.48 s, total: 21min 55s
# Wall time: 1h 37min 8s
#            model fit_time score_time test_accuracy test_f1_score test_roc_auc  \
# 0   XGB ohe base   459.71   0.769887      0.860811     0.0172662     0.503403
# 1   XGB ohe base   464.63   0.681529      0.861473     0.0257972     0.505664
# 2   XGB ohe base   492.07    0.54449      0.861263     0.0257603     0.505518
# 3    XGB te base  465.337   0.671857      0.859843      0.079009     0.517328
# 4    XGB te base  487.828   0.579191      0.859436     0.0879339     0.519423
# 5    XGB te base  493.614   0.871336       0.85897     0.0912672     0.520061
# 6  XGB tecv base  507.402   0.569767      0.859996     0.0797053     0.517571
# 7  XGB tecv base  483.502    1.03061      0.858569      0.081403      0.51738
# 8  XGB tecv base  510.853   0.607249      0.859887      0.089404     0.519977
#
#   test_log_loss
# 0       4.80742
# 1       4.78454
# 2       4.79182
# 3       4.84085
# 4       4.85493
# 5       4.87102
# 6       4.83558
# 7       4.88485
# 8       4.83934

# %% [markdown]
# ### Tuned models

# %%
estimator = XGBClassifier()

gs = GridSearchCV(estimator,
                  {'max_depth': [2, 5, 10],
                   'learning_rate':[0.05, 0.5, 1.0],
                   'n_estimators': [10, 100, 500]},
                  scoring='f1',
                  cv=3,
                  n_jobs=-1)

# %%
# %%time

gs.fit(X_train_ohe, y_train)
xgb_ohe = pd.DataFrame(gs.cv_results_)
xgb_ohe_bp = gs.best_params_
xgb_ohe_bp
# Out:
# /home/jupyter-igor.lopez/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:02:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CPU times: user 19min 7s, sys: 2.63 s, total: 19min 10s
# Wall time: 7h 5min 24s
# {'learning_rate': 1.0, 'max_depth': 10, 'n_estimators': 500}

# %%
# %%time

gs.fit(X_train_te, y_train)
xgb_te = pd.DataFrame(gs.cv_results_)
xgb_te_bp = gs.best_params_
xgb_te_bp
# Out:
# /home/jupyter-igor.lopez/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [03:04:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CPU times: user 19min 35s, sys: 3.64 s, total: 19min 38s
# Wall time: 4h 40min 49s
# {'learning_rate': 1.0, 'max_depth': 10, 'n_estimators': 500}

# %%
models_xgb_tuned = [
    ('XGB ohe tuned', XGBClassifier(**xgb_ohe_bp, use_label_encoder=False)),
    ('XGB te tuned', XGBClassifier(**xgb_te_bp, use_label_encoder=False)),
    ('XGB tecv tuned', XGBClassifier(**xgb_te_bp, use_label_encoder=False))]

# %%
# %%time

eval_report(models_xgb_tuned)
# Out:
# [03:36:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB ohe tuned
# Train Accuracy: 98.786 %
# Test Accuracy: 82.296 %
# Train F1: 95.451 %
# Test F1: 19.017 %
#
# XGB ohe tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90     16905
#            1       0.26      0.15      0.19      2723
#
#     accuracy                           0.82     19628
#    macro avg       0.57      0.54      0.55     19628
# weighted avg       0.79      0.82      0.80     19628
#
#
#
# [03:56:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB te tuned
# Train Accuracy: 99.097 %
# Test Accuracy: 81.664 %
# Train F1: 96.669 %
# Test F1: 18.996 %
#
# XGB te tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90     16905
#            1       0.25      0.15      0.19      2723
#
#     accuracy                           0.82     19628
#    macro avg       0.56      0.54      0.54     19628
# weighted avg       0.78      0.82      0.80     19628
#
#
#
# [04:24:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB tecv tuned
# Train Accuracy: 99.613 %
# Test Accuracy: 81.98 %
# Train F1: 98.59 %
# Test F1: 18.106 %
#
# XGB tecv tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90     16905
#            1       0.24      0.14      0.18      2723
#
#     accuracy                           0.82     19628
#    macro avg       0.56      0.54      0.54     19628
# weighted avg       0.78      0.82      0.80     19628
#
#
#
# CPU times: user 54min 2s, sys: 4.6 s, total: 54min 7s
# Wall time: 1h 18min 20s

# %% [markdown]
# ## Boosting DTC

# %% [markdown]
# ### Base models

# %%
models_adb_base = [
    ('ADB ohe base', AdaBoostClassifier(DecisionTreeClassifier())),
    ('ADB te base', AdaBoostClassifier(DecisionTreeClassifier())),
    ('ADB tecv base', AdaBoostClassifier(DecisionTreeClassifier()))]

# %%
# %%time

eval_report(models_adb_base)
# Out:
# ADB ohe base
# Train Accuracy: 99.613 %
# Test Accuracy: 80.762 %
# Train F1: 98.592 %
# Test F1: 17.913 %
#
# ADB ohe base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89     16905
#            1       0.22      0.15      0.18      2723
#
#     accuracy                           0.81     19628
#    macro avg       0.54      0.53      0.54     19628
# weighted avg       0.78      0.81      0.79     19628
#
#
#
# ADB te base
# Train Accuracy: 99.097 %
# Test Accuracy: 82.933 %
# Train F1: 96.67 %
# Test F1: 17.447 %
#
# ADB te base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     16905
#            1       0.27      0.13      0.17      2723
#
#     accuracy                           0.83     19628
#    macro avg       0.57      0.54      0.54     19628
# weighted avg       0.79      0.83      0.80     19628
#
#
#
# ADB tecv base
# Train Accuracy: 99.613 %
# Test Accuracy: 82.55 %
# Train F1: 98.601 %
# Test F1: 18.549 %
#
# ADB tecv base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     16905
#            1       0.26      0.14      0.19      2723
#
#     accuracy                           0.83     19628
#    macro avg       0.57      0.54      0.54     19628
# weighted avg       0.79      0.83      0.80     19628
#
#
#
# CPU times: user 1min 4s, sys: 81 µs, total: 1min 4s
# Wall time: 2min 52s

# %%
# %%time

adb_base = eval_multi(models_adb_base)
results = pd.concat([results, adb_base], ignore_index=True)
adb_base
# Out:
# CPU times: user 3min 2s, sys: 0 ns, total: 3min 2s
# Wall time: 8min 17s
#            model fit_time score_time test_accuracy test_f1_score test_roc_auc  \
# 0   ADB ohe base  74.6946    0.41202      0.797127      0.183012      0.53147
# 1   ADB ohe base  84.5195   0.467047      0.819493      0.165764      0.52997
# 2   ADB ohe base   86.532   0.469261      0.829775      0.146616     0.525922
# 3    ADB te base  15.5004   0.533177      0.824893      0.179518       0.5368
# 4    ADB te base  11.5736   0.400946      0.813888      0.196613     0.541351
# 5    ADB te base  11.4273   0.489868      0.820655      0.190432       0.5402
# 6  ADB tecv base  15.8835   0.406371      0.836764      0.182653     0.540917
# 7  ADB tecv base  16.6924   0.594666      0.833045      0.165946     0.533833
# 8  ADB tecv base  16.5244   0.394979      0.835991      0.176937     0.538623
#
#   test_log_loss
# 0       7.00707
# 1       6.23455
# 2       5.87939
# 3       6.04803
# 4       6.42813
# 5        6.1944
# 6       5.63801
# 7       5.76647
# 8        5.6647

# %% [markdown]
# ### Tuned models

# %%
estimator = AdaBoostClassifier(DecisionTreeClassifier())

gs = GridSearchCV(estimator,
                  {'learning_rate': [0.1 ,0.5, 1, 5],
                   'n_estimators': [10, 50, 100]},
                  cv=3,
                  n_jobs=-1,
                  verbose=10)

# %%
# %%time

gs.fit(X_train_ohe, y_train)
adb_ohe = pd.DataFrame(gs.cv_results_)
adb_ohe_bp = gs.best_params_
adb_ohe_bp
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# CPU times: user 3min 35s, sys: 123 ms, total: 3min 35s
# Wall time: 1h 8min 48s
# {'learning_rate': 0.5, 'n_estimators': 100}

# %%
# %%time

gs.fit(X_train_te, y_train)
adb_te = pd.DataFrame(gs.cv_results_)
adb_te_bp = gs.best_params_
adb_te_bp
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# CPU times: user 16 s, sys: 127 ms, total: 16.1 s
# Wall time: 4min 45s
# {'learning_rate': 0.5, 'n_estimators': 100}

# %%
models_adb_tuned = [
    ('ADB ohe tuned', AdaBoostClassifier(DecisionTreeClassifier(), **adb_ohe_bp)),
    ('ADB te tuned', AdaBoostClassifier(DecisionTreeClassifier(), **adb_te_bp)),
    ('ADB tecv tuned', AdaBoostClassifier(DecisionTreeClassifier(), **adb_te_bp))]

# %%
# %%time

eval_report(models_adb_tuned)
# Out:
# ADB ohe tuned
# Train Accuracy: 99.613 %
# Test Accuracy: 85.363 %
# Train F1: 98.591 %
# Test F1: 13.386 %
#
# ADB ohe tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92     16905
#            1       0.37      0.08      0.13      2723
#
#     accuracy                           0.85     19628
#    macro avg       0.62      0.53      0.53     19628
# weighted avg       0.80      0.85      0.81     19628
#
#
#
# ADB te tuned
# Train Accuracy: 99.097 %
# Test Accuracy: 82.922 %
# Train F1: 96.674 %
# Test F1: 18.798 %
#
# ADB te tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     16905
#            1       0.28      0.14      0.19      2723
#
#     accuracy                           0.83     19628
#    macro avg       0.57      0.54      0.55     19628
# weighted avg       0.79      0.83      0.81     19628
#
#
#
# ADB tecv tuned
# Train Accuracy: 99.613 %
# Test Accuracy: 84.665 %
# Train F1: 98.596 %
# Test F1: 14.586 %
#
# ADB tecv tuned classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92     16905
#            1       0.32      0.09      0.15      2723
#
#     accuracy                           0.85     19628
#    macro avg       0.59      0.53      0.53     19628
# weighted avg       0.79      0.85      0.81     19628
#
#
#
# CPU times: user 4min 56s, sys: 27 ms, total: 4min 56s
# Wall time: 9min 57s

# %%
# %%time

adb_tuned = eval_multi(models_adb_tuned)
results = pd.concat([results, adb_tuned], ignore_index=True)
adb_tuned
# Out:
# CPU times: user 14min 33s, sys: 106 ms, total: 14min 33s
# Wall time: 29min 19s
#             model fit_time score_time test_accuracy test_f1_score  \
# 0   ADB ohe tuned  281.074   0.934157      0.850825      0.108404
# 1   ADB ohe tuned  313.682    1.01755      0.849195      0.109507
# 2   ADB ohe tuned  370.977    1.01575      0.852448      0.110565
# 3    ADB te tuned  26.5417   0.796698      0.839413      0.151319
# 4    ADB te tuned   27.495   0.871238      0.841145      0.160474
# 5    ADB te tuned  27.3013   0.800802      0.837774      0.150027
# 6  ADB tecv tuned   29.118   0.855958      0.850978      0.153891
# 7  ADB tecv tuned  32.0411    0.88467      0.848736      0.136165
# 8  ADB tecv tuned  39.7046   0.912491      0.850257      0.137364
#
#   test_roc_auc test_log_loss
# 0      0.52134       5.15233
# 1     0.521026       5.20864
# 2     0.522594       5.09627
# 3     0.530588        5.5465
# 4     0.534222       5.48668
# 5     0.529641        5.6031
# 6      0.53499       5.14705
# 7      0.52877       5.22448
# 8     0.529644       5.17195

# %% [markdown]
# ## Voting Classifier from top performers

# %%
models_vot = [
    ('VOT ohe base', VotingClassifier(estimators=[('xgb', XGBClassifier(**xgb_ohe_bp, use_label_encoder=False)),
                                                  ('dtc', DecisionTreeClassifier(**dtc_ohe_bp)),
                                                  ('rfc', RandomForestClassifier(**rfc_ohe_bp))])),
    ('VOT te base', VotingClassifier(estimators=[('xgb', XGBClassifier(**xgb_te_bp, use_label_encoder=False)),
                                                 ('dtc', DecisionTreeClassifier(**dtc_te_bp)),
                                                 ('rfc', RandomForestClassifier(**rfc_te_bp))])),
    ('VOT tecv base', VotingClassifier(estimators=[('xgb', XGBClassifier(**xgb_te_bp, use_label_encoder=False)),
                                                 ('dtc', DecisionTreeClassifier(**dtc_te_bp)),
                                                 ('rfc', RandomForestClassifier(**rfc_te_bp))]))]

# %%
# %%time

eval_report(models_vot)
# Out:
# [06:58:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VOT ohe base
# Train Accuracy: 91.593 %
# Test Accuracy: 86.127 %
# Train F1: 56.609 %
# Test F1: 8.899 %
#
# VOT ohe base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92     16905
#            1       0.50      0.05      0.09      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.68      0.52      0.51     19628
# weighted avg       0.82      0.86      0.81     19628
#
#
#
# [07:05:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VOT te base
# Train Accuracy: 89.717 %
# Test Accuracy: 85.531 %
# Train F1: 41.299 %
# Test F1: 9.323 %
#
# VOT te base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92     16905
#            1       0.36      0.05      0.09      2723
#
#     accuracy                           0.86     19628
#    macro avg       0.61      0.52      0.51     19628
# weighted avg       0.80      0.86      0.81     19628
#
#
#
# [07:11:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VOT tecv base
# Train Accuracy: 89.836 %
# Test Accuracy: 85.358 %
# Train F1: 42.291 %
# Test F1: 7.944 %
#
# VOT tecv base classification report on test
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92     16905
#            1       0.31      0.05      0.08      2723
#
#     accuracy                           0.85     19628
#    macro avg       0.59      0.51      0.50     19628
# weighted avg       0.79      0.85      0.80     19628
#
#
#
# CPU times: user 18min 56s, sys: 1.58 s, total: 18min 58s
# Wall time: 19min 11s

# %%
# %%time

vot = eval_multi(models_vot)
results = pd.concat([results, vot], ignore_index=True)
vot
# Out:
# [07:17:36] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:18:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:19:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:20:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:21:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:21:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:22:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:22:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:23:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:24:14] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:24:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:25:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CPU times: user 15min 21s, sys: 915 ms, total: 15min 22s
# Wall time: 8min 38s
#            model fit_time score_time test_accuracy test_f1_score test_roc_auc  \
# 0   VOT ohe base  56.6371   0.575895      0.861422     0.0678547     0.515316
# 1   VOT ohe base  46.8448   0.581612      0.858824     0.0629016     0.512906
# 2   VOT ohe base  47.0416   0.594206      0.859377     0.0605854     0.512592
# 3    VOT te base  30.8506   0.410845      0.854952     0.0819091     0.515875
# 4    VOT te base  30.5925   0.428338      0.854748     0.0870957     0.517164
# 5    VOT te base   30.595   0.452896      0.854231     0.0821303     0.515615
# 6  VOT tecv base  33.9493   0.446089      0.858009     0.0942476     0.520424
# 7  VOT tecv base  33.7125   0.460018      0.853933     0.0878142     0.516999
# 8  VOT tecv base  33.9328   0.437529      0.856269      0.094382     0.519726
#
#   test_log_loss
# 0        4.7863
# 1       4.87605
# 2       4.85694
# 3       5.00979
# 4       5.01683
# 5       5.03468
# 6       4.90421
# 7       5.04498
# 8       4.96429

# %% [markdown]
# ## Neural network

# %%
# plot function

def plot_metric_nn(history, metric):
    history_dict = history.history
    values = history_dict[metric]
    if 'val_' + metric in history_dict.keys():  
        val_values = history_dict['val_' + metric]

    epochs = range(1, len(values) + 1)

    if 'val_' + metric in history_dict.keys():  
        plt.plot(epochs, val_values, label='Validation')
    plt.semilogy(epochs, values, label='Training')

    if 'val_' + metric in history_dict.keys():  
        plt.title('Training and validation %s' % metric)
    else:
        plt.title('Training %s' % metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.grid()

    plt.show()

# %%
# prepare vectors

X_train_nn = X_train_tecv.values
y_train_nn = y_train.values
y_train_nn_tuple = to_categorical(y_train.values)

X_test_nn = X_test_tecv.values
y_test_nn = y_test.values
y_test_nn_tuple = to_categorical(y_test.values)

# %% [markdown]
# ### 1st iteration

# %%
# first approximation, 3 layers and softmax activation at last. Output is a tuple
# tanh activating first two layers shows the best performance

def build_model():
    m = models.Sequential()
    m.add(layers.Dense(32, input_shape=(X_train_nn.shape[1],), activation='tanh'))
    m.add(layers.Dense(16, activation='tanh'))
    m.add(layers.Dense(2, activation='softmax'))
    return m

# optimizer is rmsprop

model = build_model()

model.compile(
    optimizer = optimizers.RMSprop(),
    loss = losses.categorical_crossentropy,
    metrics = metrics.categorical_accuracy)

h = model.fit(X_train_nn,
              y_train_nn_tuple,
              epochs = 20,
              batch_size = 320,
              validation_split = .2)

plot_metric_nn(h, 'loss')
plot_metric_nn(h, 'categorical_accuracy')
# Out:
# Epoch 1/20
# 148/148 [==============================] - 1s 2ms/step - loss: 0.4084 - categorical_accuracy: 0.8558 - val_loss: 0.3833 - val_categorical_accuracy: 0.8647
# Epoch 2/20
# 148/148 [==============================] - 0s 975us/step - loss: 0.3885 - categorical_accuracy: 0.8604 - val_loss: 0.3799 - val_categorical_accuracy: 0.8647
# Epoch 3/20
# 148/148 [==============================] - 0s 962us/step - loss: 0.3841 - categorical_accuracy: 0.8605 - val_loss: 0.3777 - val_categorical_accuracy: 0.8647
# Epoch 4/20
# 148/148 [==============================] - 0s 965us/step - loss: 0.3808 - categorical_accuracy: 0.8606 - val_loss: 0.3703 - val_categorical_accuracy: 0.8650
# Epoch 5/20
# 148/148 [==============================] - 0s 951us/step - loss: 0.3778 - categorical_accuracy: 0.8611 - val_loss: 0.3740 - val_categorical_accuracy: 0.8655
# Epoch 6/20
# 148/148 [==============================] - 0s 938us/step - loss: 0.3758 - categorical_accuracy: 0.8604 - val_loss: 0.3687 - val_categorical_accuracy: 0.8655
# Epoch 7/20
# 148/148 [==============================] - 0s 938us/step - loss: 0.3745 - categorical_accuracy: 0.8610 - val_loss: 0.3713 - val_categorical_accuracy: 0.8650
# Epoch 8/20
# 148/148 [==============================] - 0s 964us/step - loss: 0.3736 - categorical_accuracy: 0.8611 - val_loss: 0.3665 - val_categorical_accuracy: 0.8653
# Epoch 9/20
# 148/148 [==============================] - 0s 980us/step - loss: 0.3730 - categorical_accuracy: 0.8615 - val_loss: 0.3634 - val_categorical_accuracy: 0.8663
# Epoch 10/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3724 - categorical_accuracy: 0.8612 - val_loss: 0.3717 - val_categorical_accuracy: 0.8653
# Epoch 11/20
# 148/148 [==============================] - 0s 943us/step - loss: 0.3720 - categorical_accuracy: 0.8615 - val_loss: 0.3646 - val_categorical_accuracy: 0.8658
# Epoch 12/20
# 148/148 [==============================] - 0s 966us/step - loss: 0.3722 - categorical_accuracy: 0.8617 - val_loss: 0.3867 - val_categorical_accuracy: 0.8596
# Epoch 13/20
# 148/148 [==============================] - 0s 971us/step - loss: 0.3721 - categorical_accuracy: 0.8615 - val_loss: 0.3634 - val_categorical_accuracy: 0.8662
# Epoch 14/20
# 148/148 [==============================] - 0s 973us/step - loss: 0.3714 - categorical_accuracy: 0.8614 - val_loss: 0.3695 - val_categorical_accuracy: 0.8635
# Epoch 15/20
# 148/148 [==============================] - 0s 965us/step - loss: 0.3717 - categorical_accuracy: 0.8615 - val_loss: 0.3704 - val_categorical_accuracy: 0.8643
# Epoch 16/20
# 148/148 [==============================] - 0s 976us/step - loss: 0.3714 - categorical_accuracy: 0.8615 - val_loss: 0.3704 - val_categorical_accuracy: 0.8652
# Epoch 17/20
# 148/148 [==============================] - 0s 976us/step - loss: 0.3713 - categorical_accuracy: 0.8614 - val_loss: 0.3818 - val_categorical_accuracy: 0.8616
# Epoch 18/20
# 148/148 [==============================] - 0s 979us/step - loss: 0.3714 - categorical_accuracy: 0.8615 - val_loss: 0.3639 - val_categorical_accuracy: 0.8656
# Epoch 19/20
# 148/148 [==============================] - 0s 960us/step - loss: 0.3711 - categorical_accuracy: 0.8618 - val_loss: 0.3743 - val_categorical_accuracy: 0.8633
# Epoch 20/20
# 148/148 [==============================] - 0s 977us/step - loss: 0.3710 - categorical_accuracy: 0.8616 - val_loss: 0.3739 - val_categorical_accuracy: 0.8653

# %%
y_pred_nn = model.predict(X_test_nn)
y_pred_nn = y_pred_nn[:, 1]
y_pred_nn = (y_pred_nn > 0.5)
cm = confusion_matrix(y_test_nn, y_pred_nn)
print(cm)
# Out:
# [[16879    26]
#  [ 2712    11]]

# %%
model.evaluate(X_test_nn, y_test_nn_tuple)
# Out:
# 614/614 [==============================] - 0s 512us/step - loss: 0.4061 - categorical_accuracy: 0.8605
# [0.40606486797332764, 0.8605054020881653]

# %% [markdown]
# ### 2nd iteration

# %%
# from different optimizers on this neural network adamax optimizer works the best

model2 = build_model()
model2.compile(
    optimizer = 'adamax',
    loss = losses.categorical_crossentropy,
    metrics = metrics.categorical_accuracy)

h2 = model2.fit(X_train_nn,
              y_train_nn_tuple,
              epochs = 20,
              batch_size = 320,
              validation_split = .2)

plot_metric_nn(h2, 'loss')
plot_metric_nn(h2, 'categorical_accuracy')
# Out:
# Epoch 1/20
# 148/148 [==============================] - 0s 2ms/step - loss: 0.4141 - categorical_accuracy: 0.8604 - val_loss: 0.3973 - val_categorical_accuracy: 0.8647
# Epoch 2/20
# 148/148 [==============================] - 0s 979us/step - loss: 0.4034 - categorical_accuracy: 0.8604 - val_loss: 0.3919 - val_categorical_accuracy: 0.8647
# Epoch 3/20
# 148/148 [==============================] - 0s 985us/step - loss: 0.3986 - categorical_accuracy: 0.8604 - val_loss: 0.3867 - val_categorical_accuracy: 0.8647
# Epoch 4/20
# 148/148 [==============================] - 0s 982us/step - loss: 0.3943 - categorical_accuracy: 0.8604 - val_loss: 0.3832 - val_categorical_accuracy: 0.8647
# Epoch 5/20
# 148/148 [==============================] - 0s 964us/step - loss: 0.3909 - categorical_accuracy: 0.8605 - val_loss: 0.3816 - val_categorical_accuracy: 0.8647
# Epoch 6/20
# 148/148 [==============================] - 0s 960us/step - loss: 0.3886 - categorical_accuracy: 0.8604 - val_loss: 0.3783 - val_categorical_accuracy: 0.8646
# Epoch 7/20
# 148/148 [==============================] - 0s 990us/step - loss: 0.3865 - categorical_accuracy: 0.8605 - val_loss: 0.3763 - val_categorical_accuracy: 0.8647
# Epoch 8/20
# 148/148 [==============================] - 0s 969us/step - loss: 0.3844 - categorical_accuracy: 0.8605 - val_loss: 0.3751 - val_categorical_accuracy: 0.8647
# Epoch 9/20
# 148/148 [==============================] - 0s 988us/step - loss: 0.3826 - categorical_accuracy: 0.8606 - val_loss: 0.3731 - val_categorical_accuracy: 0.8648
# Epoch 10/20
# 148/148 [==============================] - 0s 977us/step - loss: 0.3806 - categorical_accuracy: 0.8610 - val_loss: 0.3708 - val_categorical_accuracy: 0.8647
# Epoch 11/20
# 148/148 [==============================] - 0s 984us/step - loss: 0.3793 - categorical_accuracy: 0.8609 - val_loss: 0.3711 - val_categorical_accuracy: 0.8650
# Epoch 12/20
# 148/148 [==============================] - 0s 973us/step - loss: 0.3776 - categorical_accuracy: 0.8611 - val_loss: 0.3683 - val_categorical_accuracy: 0.8650
# Epoch 13/20
# 148/148 [==============================] - 0s 976us/step - loss: 0.3765 - categorical_accuracy: 0.8611 - val_loss: 0.3671 - val_categorical_accuracy: 0.8652
# Epoch 14/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3758 - categorical_accuracy: 0.8612 - val_loss: 0.3668 - val_categorical_accuracy: 0.8651
# Epoch 15/20
# 148/148 [==============================] - 0s 979us/step - loss: 0.3747 - categorical_accuracy: 0.8611 - val_loss: 0.3659 - val_categorical_accuracy: 0.8652
# Epoch 16/20
# 148/148 [==============================] - 0s 999us/step - loss: 0.3739 - categorical_accuracy: 0.8612 - val_loss: 0.3647 - val_categorical_accuracy: 0.8658
# Epoch 17/20
# 148/148 [==============================] - 0s 986us/step - loss: 0.3731 - categorical_accuracy: 0.8611 - val_loss: 0.3644 - val_categorical_accuracy: 0.8659
# Epoch 18/20
# 148/148 [==============================] - 0s 993us/step - loss: 0.3730 - categorical_accuracy: 0.8614 - val_loss: 0.3636 - val_categorical_accuracy: 0.8659
# Epoch 19/20
# 148/148 [==============================] - 0s 980us/step - loss: 0.3724 - categorical_accuracy: 0.8614 - val_loss: 0.3649 - val_categorical_accuracy: 0.8665
# Epoch 20/20
# 148/148 [==============================] - 0s 969us/step - loss: 0.3721 - categorical_accuracy: 0.8614 - val_loss: 0.3628 - val_categorical_accuracy: 0.8663

# %%
y_pred_nn2 = model2.predict(X_test_nn)
y_pred_nn2 = y_pred_nn2[:, 1]
y_pred_nn2 = (y_pred_nn2 > 0.5)
cm2 = confusion_matrix(y_test_nn, y_pred_nn2)
print(cm2)
# Out:
# [[16831    74]
#  [ 2697    26]]

# %%
model2.evaluate(X_test_nn, y_test_nn_tuple)
# Out:
# 614/614 [==============================] - 0s 511us/step - loss: 0.3916 - categorical_accuracy: 0.8588
# [0.3915722966194153, 0.8588241338729858]

# %% [markdown]
# ### 3rd iteration

# %%
# let's try a different network configuration, with sigmoid activation in the last layer, also adam optimizer

def build_model():
    m = models.Sequential()
    m.add(layers.Dense(32, input_shape=(X_train_nn.shape[1],), kernel_initializer='normal', activation='tanh'))
    m.add(layers.Dense(16, kernel_initializer='normal', activation='tanh'))
    m.add(layers.Dense(2, kernel_initializer='normal', activation='sigmoid'))
    return m

model3 = build_model()
model3.compile(
    optimizer = 'adam',
    loss = losses.categorical_crossentropy,
    metrics = metrics.categorical_accuracy)

h3 = model3.fit(X_train_nn,
              y_train_nn_tuple,
              epochs=20,
              batch_size=320,
              validation_split=.2)

plot_metric_nn(h3, 'loss')
plot_metric_nn(h3, 'categorical_accuracy')
# Out:
# Epoch 1/20
# 148/148 [==============================] - 0s 2ms/step - loss: 0.4607 - categorical_accuracy: 0.8573 - val_loss: 0.4013 - val_categorical_accuracy: 0.8647
# Epoch 2/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.4071 - categorical_accuracy: 0.8604 - val_loss: 0.3987 - val_categorical_accuracy: 0.8647
# Epoch 3/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.4055 - categorical_accuracy: 0.8604 - val_loss: 0.3973 - val_categorical_accuracy: 0.8647
# Epoch 4/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.4049 - categorical_accuracy: 0.8604 - val_loss: 0.3969 - val_categorical_accuracy: 0.8647
# Epoch 5/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.4046 - categorical_accuracy: 0.8604 - val_loss: 0.3972 - val_categorical_accuracy: 0.8647
# Epoch 6/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.4044 - categorical_accuracy: 0.8604 - val_loss: 0.3966 - val_categorical_accuracy: 0.8647
# Epoch 7/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.4041 - categorical_accuracy: 0.8604 - val_loss: 0.3955 - val_categorical_accuracy: 0.8647
# Epoch 8/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.4010 - categorical_accuracy: 0.8604 - val_loss: 0.3885 - val_categorical_accuracy: 0.8647
# Epoch 9/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3917 - categorical_accuracy: 0.8604 - val_loss: 0.3794 - val_categorical_accuracy: 0.8647
# Epoch 10/20
# 148/148 [==============================] - 0s 989us/step - loss: 0.3864 - categorical_accuracy: 0.8604 - val_loss: 0.3752 - val_categorical_accuracy: 0.8647
# Epoch 11/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3835 - categorical_accuracy: 0.8604 - val_loss: 0.3730 - val_categorical_accuracy: 0.8647
# Epoch 12/20
# 148/148 [==============================] - 0s 978us/step - loss: 0.3815 - categorical_accuracy: 0.8604 - val_loss: 0.3715 - val_categorical_accuracy: 0.8647
# Epoch 13/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3798 - categorical_accuracy: 0.8604 - val_loss: 0.3707 - val_categorical_accuracy: 0.8647
# Epoch 14/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3779 - categorical_accuracy: 0.8604 - val_loss: 0.3676 - val_categorical_accuracy: 0.8647
# Epoch 15/20
# 148/148 [==============================] - 0s 995us/step - loss: 0.3762 - categorical_accuracy: 0.8605 - val_loss: 0.3659 - val_categorical_accuracy: 0.8647
# Epoch 16/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3746 - categorical_accuracy: 0.8609 - val_loss: 0.3645 - val_categorical_accuracy: 0.8650
# Epoch 17/20
# 148/148 [==============================] - 0s 987us/step - loss: 0.3728 - categorical_accuracy: 0.8612 - val_loss: 0.3634 - val_categorical_accuracy: 0.8651
# Epoch 18/20
# 148/148 [==============================] - 0s 995us/step - loss: 0.3722 - categorical_accuracy: 0.8616 - val_loss: 0.3628 - val_categorical_accuracy: 0.8653
# Epoch 19/20
# 148/148 [==============================] - 0s 997us/step - loss: 0.3716 - categorical_accuracy: 0.8616 - val_loss: 0.3626 - val_categorical_accuracy: 0.8652
# Epoch 20/20
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3714 - categorical_accuracy: 0.8614 - val_loss: 0.3629 - val_categorical_accuracy: 0.8658

# %%
y_pred_nn3 = model3.predict(X_test_nn)
y_pred_nn3 = y_pred_nn3[:, 1]
y_pred_nn3 = (y_pred_nn3 > 0.5)
cm3 = confusion_matrix(y_test_nn, y_pred_nn3)
print(cm3)
# Out:
# [[16864    41]
#  [ 2707    16]]

# %%
model3.evaluate(X_test_nn, y_test_nn_tuple)
# Out:
# 614/614 [==============================] - 0s 511us/step - loss: 0.3919 - categorical_accuracy: 0.8593
# [0.3919207751750946, 0.8592826724052429]

# %% [markdown]
# # Plot results comparison

# %%
results.dtypes
# Out:
# model            object
# fit_time         object
# score_time       object
# test_accuracy    object
# test_f1_score    object
# test_roc_auc     object
# test_log_loss    object
# dtype: object

# %%
results2 = results.loc[:, results.columns != 'model'].astype(float)
results_h = pd.concat([results['model'],results2], axis=1)
results_h.dtypes
# Out:
# model             object
# fit_time         float64
# score_time       float64
# test_accuracy    float64
# test_f1_score    float64
# test_roc_auc     float64
# test_log_loss    float64
# dtype: object

# %%
results_h.groupby('model', as_index=False).agg('mean')
# Out:
#              model    fit_time  score_time  test_accuracy  test_f1_score  \
# 0     ADB ohe base   81.915352    0.449443       0.815465       0.165131
# 1    ADB ohe tuned  321.911095    0.989149       0.850823       0.109492
# 2      ADB te base   12.833748    0.474663       0.819812       0.188854
# 3     ADB te tuned   27.112672    0.822913       0.839444       0.153940
# 4    ADB tecv base   16.366768    0.465339       0.835267       0.175178
# 5   ADB tecv tuned   33.621218    0.884373       0.849991       0.142473
# 6     DTC ohe base   37.037653    0.120945       0.793013       0.187468
# 7    DTC ohe tuned    5.796069    0.035008       0.850449       0.085547
# 8      DTC te base    0.614602    0.054674       0.772923       0.223178
# 9     DTC te tuned    0.410874    0.045001       0.833280       0.157557
# 10   DTC tecv base    1.518645    0.118266       0.767913       0.222116
# 11  DTC tecv tuned    0.518768    0.035898       0.832617       0.168746
# 12    KNC ohe base    0.083047  232.147658       0.842824       0.087367
# 13   KNC ohe tuned    0.064962  255.002450       0.859093       0.021693
# 14     KNC te base    0.022794   87.310963       0.843299       0.131075
# 15    KNC te tuned    0.005369  115.126626       0.858958       0.053766
# 16   KNC tecv base    0.033876   90.501861       0.844488       0.123611
# 17  KNC tecv tuned    0.101500  167.758488       0.859297       0.040309
# 18    RFC ohe base  145.513401    1.806777       0.862320       0.071474
# 19   RFC ohe tuned   44.995559    0.510061       0.862932       0.041103
# 20     RFC te base   15.726640    1.501249       0.854389       0.119695
# 21    RFC te tuned    8.662469    0.637186       0.861726       0.017818
# 22   RFC tecv base   13.738121    1.466261       0.858890       0.105637
# 23  RFC tecv tuned    7.611484    0.530816       0.861675       0.011868
# 24    VOT ohe base   50.174495    0.583904       0.859875       0.063781
# 25     VOT te base   30.679360    0.430693       0.854644       0.083712
# 26   VOT tecv base   33.864893    0.447879       0.856071       0.092148
# 27    XGB ohe base  472.136746    0.665302       0.861182       0.022941
# 28     XGB te base  482.259932    0.707462       0.859416       0.086070
# 29   XGB tecv base  500.585688    0.735876       0.859484       0.083504
#
#     test_roc_auc  test_log_loss
# 0       0.529121       6.373671
# 1       0.521653       5.152412
# 2       0.539450       6.223517
# 3       0.531484       5.545427
# 4       0.537791       5.689726
# 5       0.531135       5.181158
# 6       0.532575       7.149143
# 7       0.514862       5.165316
# 8       0.547363       7.843073
# 9       0.530884       5.758355
# 10      0.545996       8.016115
# 11      0.534712       5.781232
# 12      0.512027       5.428690
# 13      0.503444       4.866742
# 14      0.525298       5.412270
# 15      0.510761       4.871437
# 16      0.523420       5.371210
# 17      0.507774       4.859705
# 18      0.516617       4.755295
# 19      0.509832       4.734177
# 20      0.525932       5.029232
# 21      0.504047       4.775823
# 22      0.523819       4.873787
# 23      0.502734       4.777582
# 24      0.513605       4.839763
# 25      0.516218       5.020431
# 26      0.519050       4.971158
# 27      0.504862       4.794593
# 28      0.518937       4.855602
# 29      0.518309       4.853255

# %%
fig, ax = plt.subplots(6, figsize=(20,24))
fig.tight_layout(pad=3, rect=[0, 0.01, 1, 0.95])
fig.subplots_adjust(hspace=.75)
fig.suptitle('Models Comparison - CV on test set', size=18)

sns.barplot(x='model', y='test_accuracy', data=results_h, color='cornflowerblue', ax=ax[0]).set_title('Accuracy')
ax[0].tick_params(axis='x', rotation=45)
ax[0].yaxis.grid(True)
ax[0].xaxis.grid(False)

sns.barplot(x='model', y='test_f1_score', data=results_h, color='gold', ax=ax[1]).set_title('F1 score')
ax[1].tick_params(axis='x', rotation=45)
ax[1].yaxis.grid(True)
ax[1].xaxis.grid(False)

sns.barplot(x='model', y='test_roc_auc', data=results_h, color='aquamarine', ax=ax[2]).set_title('ROC AUC')
ax[2].tick_params(axis='x', rotation=45)
ax[2].yaxis.grid(True)
ax[2].xaxis.grid(False)

sns.barplot(x='model', y='test_log_loss', data=results_h, color='lightcoral', ax=ax[3]).set_title('Logloss')
ax[3].tick_params(axis='x', rotation=45)
ax[3].yaxis.grid(True)
ax[3].xaxis.grid(False)

sns.barplot(x='model', y='fit_time', data=results_h, color='gainsboro', ax=ax[4]).set_title('Fit Time')
ax[4].tick_params(axis='x', rotation=45)
ax[4].yaxis.grid(True)
ax[4].xaxis.grid(False)

sns.barplot(x='model', y='score_time', data=results_h, color='plum', ax=ax[5]).set_title('Score Time')
ax[5].tick_params(axis='x', rotation=45)
ax[5].yaxis.grid(True)
ax[5].xaxis.grid(False)

# %%
results.to_csv('data_files/results_main.csv', index=False)
